# %% [markdown]
# # SQL Requirement

# %%
import pandas as pd
from datetime import datetime, timedelta, time

# %%
# Source: http://web.mta.info/developers/turnstile.html
def get_data(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url))
    return pd.concat(dfs)
        
week_nums = [160903, 160910, 160917]
turnstiles_dfdb = get_data(week_nums)
turnstiles_dfdb.to_csv('data2016.csv', index=False)

# %%
from sqlalchemy import create_engine
engine = create_engine("sqlite:///turnstile.db")
dfdb = pd.read_sql('SELECT * FROM data2016;', engine)
dfdb.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST   NQR456      BMT  08/27/2016  00:00:00
# 1  A002  R051  02-00-00   59 ST   NQR456      BMT  08/27/2016  04:00:00
# 2  A002  R051  02-00-00   59 ST   NQR456      BMT  08/27/2016  08:00:00
# 3  A002  R051  02-00-00   59 ST   NQR456      BMT  08/27/2016  12:00:00
# 4  A002  R051  02-00-00   59 ST   NQR456      BMT  08/27/2016  16:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  5799442  1966041
# 1  REGULAR  5799463  1966044
# 2  REGULAR  5799492  1966079
# 3  REGULAR  5799610  1966155
# 4  REGULAR  5799833  1966214

# %% [markdown]
# # MTA Cleaning

# %%
# remove outliers per station, each has its nature
# cutoff

# %%
year = 2020

# %%
# Define list of weeks we want to pull from the MTA portal

def datelist(startdate, num_weeks):
    """
    For a given Saturday, make a list of dates for the n previous Saturdays
    """
    week_list = [startdate + ((timedelta(days=-7))*i) for i in range(num_weeks)]
    clean_weeks = [i.strftime('%y%m%d') for i in week_list]
    return clean_weeks


# Define the last Saturday we're interested in
if year == 2020:
    last = datetime(2020, 6, 27)
elif year == 2019:
    last = datetime(2019, 12, 28)

# We'll import data for the 24 weeks in a year proceeding chosen saturday
weeks_to_import = datelist(last, 26)
#weeks_to_import

# %%
def get_data_parse_dt(week_nums):
    url = "http://web.mta.info/developers/data/nyct/turnstile/turnstile_{}.txt"
    dfs = []
    for week_num in week_nums:
        file_url = url.format(week_num)
        dfs.append(pd.read_csv(file_url, parse_dates=[['DATE','TIME']], keep_date_col=True))
    return pd.concat(dfs)
        
#week_nums = [210501, 210424, 210417, 210410, 210403]
turnstiles_df = get_data_parse_dt(weeks_to_import)

# %%
turnstiles_df.columns = [column.strip() for column in turnstiles_df.columns]
turnstiles_df["STATION_LINENAME"] = turnstiles_df.STATION + turnstiles_df.LINENAME
turnstiles_df
# Out:
#                  DATE_TIME    C/A  UNIT       SCP        STATION LINENAME  \
# 0      2020-06-20 00:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 1      2020-06-20 04:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 2      2020-06-20 08:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 3      2020-06-20 12:00:00   A002  R051  02-00-00          59 ST  NQR456W
# 4      2020-06-20 16:00:00   A002  R051  02-00-00          59 ST  NQR456W
# ...                    ...    ...   ...       ...            ...      ...
# 206494 2020-01-03 04:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206495 2020-01-03 08:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206496 2020-01-03 12:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206497 2020-01-03 16:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
# 206498 2020-01-03 20:00:00  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R
#
#        DIVISION        DATE      TIME     DESC  ENTRIES    EXITS  \
# 0           BMT  06/20/2020  00:00:00  REGULAR  7424218  2522558
# 1           BMT  06/20/2020  04:00:00  REGULAR  7424220  2522559
# 2           BMT  06/20/2020  08:00:00  REGULAR  7424231  2522572
# 3           BMT  06/20/2020  12:00:00  REGULAR  7424265  2522590
# 4           BMT  06/20/2020  16:00:00  REGULAR  7424340  2522604
# ...         ...         ...       ...      ...      ...      ...
# 206494      RIT  01/03/2020  04:00:00  REGULAR     5554      420
# 206495      RIT  01/03/2020  08:00:00  REGULAR     5554      420
# 206496      RIT  01/03/2020  12:00:00  REGULAR     5554      420
# 206497      RIT  01/03/2020  16:00:00  REGULAR     5554      420
# 206498      RIT  01/03/2020  20:00:00  REGULAR     5554      420
#
#        STATION_LINENAME
# 0          59 STNQR456W
# 1          59 STNQR456W
# 2          59 STNQR456W
# 3          59 STNQR456W
# 4          59 STNQR456W
# ...                 ...
# 206494   RIT-ROOSEVELTR
# 206495   RIT-ROOSEVELTR
# 206496   RIT-ROOSEVELTR
# 206497   RIT-ROOSEVELTR
# 206498   RIT-ROOSEVELTR
#
# [5366774 rows x 13 columns]

# %%
# Drop Exits and Desc Column.  To prevent errors in multiple run of cell, errors on drop is ignored
turnstiles_df = turnstiles_df.drop(["EXITS", "DESC"], axis=1, errors="ignore")

# %%
turnstiles_daily = (turnstiles_df
                        .groupby(["C/A", "UNIT", "SCP", "STATION_LINENAME", "DATE"],as_index=False)
                        .ENTRIES.first())

# %%
turnstiles_daily[["PREV_DATE", "PREV_ENTRIES"]] = (turnstiles_daily.groupby(
    ["C/A", "UNIT", "SCP",
     "STATION_LINENAME"])[["DATE", "ENTRIES"]].apply(lambda grp: grp.shift(1)))

# %%
turnstiles_daily.head()
# Out:
#     C/A  UNIT       SCP STATION_LINENAME        DATE  ENTRIES   PREV_DATE  \
# 0  A002  R051  02-00-00     59 STNQR456W  06/29/2019  7116734         NaN
# 1  A002  R051  02-00-00     59 STNQR456W  06/30/2019  7117480  06/29/2019
# 2  A002  R051  02-00-00     59 STNQR456W  07/01/2019  7118119  06/30/2019
# 3  A002  R051  02-00-00     59 STNQR456W  07/02/2019  7119610  07/01/2019
# 4  A002  R051  02-00-00     59 STNQR456W  07/03/2019  7121181  07/02/2019
#
#    PREV_ENTRIES
# 0           NaN
# 1     7116734.0
# 2     7117480.0
# 3     7118119.0
# 4     7119610.0

# %%
# Drop the rows for the earliest date in the df
turnstiles_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)

# %%
def get_daily_counts(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        # Maybe counter is reversed?
        counter = -counter
    if counter > max_counter:
        # Maybe counter was reset to 0? 
        # print(row["ENTRIES"], row["PREV_ENTRIES"])
        counter = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter > max_counter:
        # Check it again to make sure we're not still giving a counter that's too big
        return 0
    return counter

# If counter is > 1Million, then the counter might have been reset.  
# Just set it to zero as different counters have different cycle limits
# It'd probably be a good idea to use a number even significantly smaller than 1 million as the limit!
turnstiles_daily["DAILY_ENTRIES"] = turnstiles_daily.apply(get_daily_counts, axis=1, max_counter=1000000)

# %%
turnstiles_daily
# Out:
#           C/A  UNIT       SCP STATION_LINENAME        DATE  ENTRIES  \
# 1        A002  R051  02-00-00     59 STNQR456W  06/30/2019  7117480
# 2        A002  R051  02-00-00     59 STNQR456W  07/01/2019  7118119
# 3        A002  R051  02-00-00     59 STNQR456W  07/02/2019  7119610
# 4        A002  R051  02-00-00     59 STNQR456W  07/03/2019  7121181
# 5        A002  R051  02-00-00     59 STNQR456W  07/04/2019  7122652
# ...       ...   ...       ...              ...         ...      ...
# 889613  TRAM2  R469  00-05-01   RIT-ROOSEVELTR  12/23/2019     5554
# 889614  TRAM2  R469  00-05-01   RIT-ROOSEVELTR  12/24/2019     5554
# 889615  TRAM2  R469  00-05-01   RIT-ROOSEVELTR  12/25/2019     5554
# 889616  TRAM2  R469  00-05-01   RIT-ROOSEVELTR  12/26/2019     5554
# 889617  TRAM2  R469  00-05-01   RIT-ROOSEVELTR  12/27/2019     5554
#
#          PREV_DATE  PREV_ENTRIES  DAILY_ENTRIES
# 1       06/29/2019     7116734.0          746.0
# 2       06/30/2019     7117480.0          639.0
# 3       07/01/2019     7118119.0         1491.0
# 4       07/02/2019     7119610.0         1571.0
# 5       07/03/2019     7121181.0         1471.0
# ...            ...           ...            ...
# 889613  12/22/2019        5554.0            0.0
# 889614  12/23/2019        5554.0            0.0
# 889615  12/24/2019        5554.0            0.0
# 889616  12/25/2019        5554.0            0.0
# 889617  12/26/2019        5554.0            0.0
#
# [884621 rows x 9 columns]

# %%
# For each ControlArea/UNIT/STATION combo, for each day, sum the counts from each turnstile belonging to that combo.
ca_unit_station_daily = turnstiles_daily.groupby(
    ["C/A", "UNIT", "STATION_LINENAME",
     "DATE"])[['DAILY_ENTRIES']].sum().reset_index()
ca_unit_station_daily.head()
# Out:
#     C/A  UNIT STATION_LINENAME        DATE  DAILY_ENTRIES
# 0  A002  R051     59 STNQR456W  06/30/2019         7418.0
# 1  A002  R051     59 STNQR456W  07/01/2019         6337.0
# 2  A002  R051     59 STNQR456W  07/02/2019        12758.0
# 3  A002  R051     59 STNQR456W  07/03/2019        13157.0
# 4  A002  R051     59 STNQR456W  07/04/2019        12874.0

# %%
# daily time series for each STATION, by adding up all the turnstiles in a station.
station_daily = turnstiles_daily.groupby(["STATION_LINENAME", "DATE"])[['DAILY_ENTRIES']].sum().reset_index()
station_daily
# Out:
#       STATION_LINENAME        DATE  DAILY_ENTRIES
# 0                1 AVL  06/30/2019        10815.0
# 1                1 AVL  07/01/2019        10852.0
# 2                1 AVL  07/02/2019        16994.0
# 3                1 AVL  07/03/2019        17226.0
# 4                1 AVL  07/04/2019        17614.0
# ...                ...         ...            ...
# 86277       ZEREGA AV6  12/23/2019         1055.0
# 86278       ZEREGA AV6  12/24/2019         2452.0
# 86279       ZEREGA AV6  12/25/2019         1842.0
# 86280       ZEREGA AV6  12/26/2019          790.0
# 86281       ZEREGA AV6  12/27/2019         2036.0
#
# [86282 rows x 3 columns]

# %% [markdown]
# # Turnstile data to NYC stops
# Joining stations ids to turnstile data

# %%
NYC_stops = pd.read_csv('Turnstile_data_stops_to_NYC_stops_new.csv')
NYC_stops
# Out:
#          STATION_LINENAME       STATION  LINENAME  objectid
# 0          WHITEHALL STR1  WHITEHALL ST        R1     421.0
# 1           SOUTH FERRYR1   SOUTH FERRY        R1     418.0
# 2       FULTON STACJZ2345     FULTON ST  ACJZ2345     413.0
# 3       FULTON STACJZ2345     FULTON ST  ACJZ2345     402.0
# 4       FULTON STACJZ2345     FULTON ST  ACJZ2345     360.0
# ..                    ...           ...       ...       ...
# 764          LORIMER STLG           NaN       NaN      72.0
# 765       NEWKIRK PLAZABQ           NaN       NaN     113.0
# 766         SOUTH FERRY1R           NaN       NaN     418.0
# 767  WORLD TRADE CTRACE23           NaN       NaN     409.0
# 768        WTC-CORTLANDT1           NaN       NaN     426.0
#
# [769 rows x 4 columns]

# %%
joined = station_daily.merge(NYC_stops[['STATION_LINENAME', 'objectid']], on='STATION_LINENAME', how ='outer').dropna()

# %%
joined
# Out:
#       STATION_LINENAME        DATE  DAILY_ENTRIES  objectid
# 0                1 AVL  06/30/2019        10815.0     146.0
# 1                1 AVL  07/01/2019        10852.0     146.0
# 2                1 AVL  07/02/2019        16994.0     146.0
# 3                1 AVL  07/03/2019        17226.0     146.0
# 4                1 AVL  07/04/2019        17614.0     146.0
# ...                ...         ...            ...       ...
# 98104       ZEREGA AV6  12/23/2019         1055.0      30.0
# 98105       ZEREGA AV6  12/24/2019         2452.0      30.0
# 98106       ZEREGA AV6  12/25/2019         1842.0      30.0
# 98107       ZEREGA AV6  12/26/2019          790.0      30.0
# 98108       ZEREGA AV6  12/27/2019         2036.0      30.0
#
# [94127 rows x 4 columns]

# %%
joined_and_summed = joined.groupby(['objectid', 'DATE']).agg({'DAILY_ENTRIES':'sum','STATION_LINENAME':'min'}).reset_index()
joined_and_summed
# Out:
#        objectid        DATE  DAILY_ENTRIES STATION_LINENAME
# 0           1.0  06/30/2019        11885.0        ASTOR PL6
# 1           1.0  07/01/2019        15344.0        ASTOR PL6
# 2           1.0  07/02/2019        15610.0        ASTOR PL6
# 3           1.0  07/03/2019        16549.0        ASTOR PL6
# 4           1.0  07/04/2019        15658.0        ASTOR PL6
# ...         ...         ...            ...              ...
# 84846     643.0  12/23/2019         9565.0     96 ST-2 AVEQ
# 84847     643.0  12/24/2019        15093.0     96 ST-2 AVEQ
# 84848     643.0  12/25/2019        12034.0     96 ST-2 AVEQ
# 84849     643.0  12/26/2019         5943.0     96 ST-2 AVEQ
# 84850     643.0  12/27/2019        12103.0     96 ST-2 AVEQ
#
# [84851 rows x 4 columns]

# %%
joined_and_summed.to_csv(f'{year}6m_entries.csv')

# %% [markdown]
# # Merge Arrests and Turnstile Swipes

# %%
arrests = pd.read_csv('Arrests_Assigned_250m222.csv', index_col = 0)

# %%
arrests['ARREST_DATE'] = pd.to_datetime(arrests['ARREST_DATE'], format = '%m/%d/%Y')

# %%
arrests['ARREST_DATE'].sort_values()
# Out:
# 16063    2006-01-01
# 16022    2006-01-01
# 16204    2006-01-02
# 15893    2006-01-02
# 16276    2006-01-02
#             ...
# 271581   2020-12-29
# 271600   2020-12-30
# 271560   2020-12-30
# 271538   2020-12-30
# 271596   2020-12-31
# Name: ARREST_DATE, Length: 272103, dtype: datetime64[ns]

# %%
joined['DATE'] = pd.to_datetime(joined['DATE'], format = '%m/%d/%Y')

# %%
joined.DATE.sort_values()
# Out:
# 0       2019-06-30
# 74155   2019-06-30
# 73974   2019-06-30
# 73793   2019-06-30
# 9741    2019-06-30
#            ...
# 87081   2019-12-27
# 47732   2019-12-27
# 97203   2019-12-27
# 92677   2019-12-27
# 98108   2019-12-27
# Name: DATE, Length: 94127, dtype: datetime64[ns]

# %%
joined = joined.rename({'DATE':'ARREST_DATE'}, axis=1)

# %%
arrests_turns = arrests.merge(joined, how ='left', on = ['ARREST_DATE', 'objectid'])

# %%
arrests_turns.head()
# Out:
#    ARREST_KEY ARREST_DATE ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  \
# 0    24079639  2006-08-30           K               84                  1
# 1   194556724  2019-03-11           K               73                  1
# 2   193173213  2019-02-05           K               78                  1
# 3   192365846  2019-01-16           B               44                  0
# 4   201664879  2019-08-28           K               83                  0
#
#   AGE_GROUP PERP_SEX       PERP_RACE   Latitude  Longitude  \
# 0     18-24        M           BLACK  40.691465 -73.987348
# 1     25-44        M           BLACK  40.662563 -73.908921
# 2     25-44        M  WHITE HISPANIC  40.684061 -73.977459
# 3     45-64        M           BLACK  40.827820 -73.925931
# 4     25-44        M  BLACK HISPANIC  40.702480 -73.920451
#
#                            geometry  index     line  \
# 0  POINT (-73.98734802 40.69146491)      0    A-C-F
# 1  POINT (-73.90892112 40.66256275)      1      3-4
# 2  POINT (-73.97745929 40.68406075)      3  2-3-4-5
# 3   POINT (-73.92593076 40.8278199)      4      B-D
# 4  POINT (-73.92045095 40.70248032)      6        L
#
#                              name  \
# 0              Jay St - MetroTech
# 1                    Rockaway Ave
# 2  Atlantic Av - Barclay's Center
# 3       161st St - Yankee Stadium
# 4                      DeKalb Ave
#
#                                                notes  objectid  \
# 0              A,F-all times, C-all times exc nights     368.0
# 1                        4-nights, 3-all other times     218.0
# 2  2,4-all times, 3-all times exc nights, 5-weekdays     116.0
# 3  B-rush hours, D-all times, skips rush hours AM...     297.0
# 4                                        L-all times     235.0
#
#   STATION_LINENAME  DAILY_ENTRIES
# 0              NaN            NaN
# 1              NaN            NaN
# 2              NaN            NaN
# 3              NaN            NaN
# 4       DEKALB AVL        10397.0

# %%
#next we'll delete null values from the dataset (some arrests occur before we have turnstile data)
print('Null entry diffs', arrests_turns.DAILY_ENTRIES.isnull().sum())
arrests_turns.dropna(subset = ['DAILY_ENTRIES'], how='any', inplace=True)
print('Clean Data len:', len(arrests_turns))
# Out:
# Null entry diffs 270874
# Clean Data len: 1427

# %%
results = arrests_turns.groupby('objectid').agg({'ARREST_KEY': 'count'}).rename({'ARREST_KEY': 'arrests'}, axis=1)

# %%
results.arrests.sort_values(ascending=False).to_csv(f'{year}6m_arrests.csv')

# %%
results.arrests.sum()
# Out:
# 1427
